# %%
# %matplotlib inline
import pandas as pd
import scipy.stats as stats
import numpy as np
table = pd.read_csv('consolidado.csv')
table.head()
#vsm x =valor del salario minimo febrero
#vsm y =valor del salario enero
# Out:
#    key  vsm_actual_x  SaldoInsolutoActual_x  PagosVencidosMeses_x  \
# 0    0      2686.144                 204.43                     0
# 1    1      2686.144                  42.63                     0
# 2    2      2686.144                 189.87                     0
# 3    3      2686.144                  51.81                     0
# 4    4      2686.144                 197.55                     0
#
#    vsm_actual_y  SaldoInsolutoActual_y  PagosVencidosMeses_y   estado
# 0      2686.144                 203.19                     0  Jalisco
# 1      2686.144                  42.78                     0  Jalisco
# 2      2686.144                 190.63                     0  Jalisco
# 3      2686.144                  52.00                     0  Jalisco
# 4      2686.144                 194.85                     0  Jalisco

# %%
table.columns
# Out:
# Index(['key', 'vsm_actual_x', 'SaldoInsolutoActual_x', 'PagosVencidosMeses_x',
#        'vsm_actual_y', 'SaldoInsolutoActual_y', 'PagosVencidosMeses_y',
#        'estado'],
#       dtype='object')

# %%
table["vsm_enero"] = table["vsm_actual_y"]
table["vsm_febrero"] = table["vsm_actual_x"]
table["PagosVencidos_enero"] = table["PagosVencidosMeses_y"]
table["PagosVencidos_febrero"] = table["PagosVencidosMeses_x"]
table["RemainingDebt_enero"] = table["SaldoInsolutoActual_y"]
table["RemainingDebt_febrero"] = table["SaldoInsolutoActual_x"]

Table = table[["key", "vsm_enero", "vsm_febrero", "PagosVencidos_enero", "PagosVencidos_febrero", "RemainingDebt_enero", "RemainingDebt_febrero", "estado"]]
Table.head()
# Out:
#    key  vsm_enero  vsm_febrero  PagosVencidos_enero  PagosVencidos_febrero  \
# 0    0   2686.144     2686.144                    0                      0
# 1    1   2686.144     2686.144                    0                      0
# 2    2   2686.144     2686.144                    0                      0
# 3    3   2686.144     2686.144                    0                      0
# 4    4   2686.144     2686.144                    0                      0
#
#    RemainingDebt_enero  RemainingDebt_febrero   estado
# 0               203.19                 204.43  Jalisco
# 1                42.78                  42.63  Jalisco
# 2               190.63                 189.87  Jalisco
# 3                52.00                  51.81  Jalisco
# 4               194.85                 197.55  Jalisco

# %%
Estados = Table["estado"].value_counts()
#print(Estados)
#print(len(Estados))

# %%
Table["PagosVencidos_enero"].value_counts()
# Out:
# 0    16856
# 1     1289
# 2      248
# 3       53
# Name: PagosVencidos_enero, dtype: int64

# %%
Table["PagosVencidos_febrero"].value_counts()
# Out:
# 0    16509
# 1     1490
# 2      344
# 3       72
# 4       31
# Name: PagosVencidos_febrero, dtype: int64

# %%
PagosVencidos_dos = Table["PagosVencidos_enero"] - Table["PagosVencidos_febrero"]
PagosVencidos_dos.value_counts()
# Out:
#  0    16636
# -1     1223
#  1      535
#  2       42
#  3       10
# dtype: int64

# %%
Table.head()
# Out:
#    key  vsm_enero  vsm_febrero  PagosVencidos_enero  PagosVencidos_febrero  \
# 0    0   2686.144     2686.144                    0                      0
# 1    1   2686.144     2686.144                    0                      0
# 2    2   2686.144     2686.144                    0                      0
# 3    3   2686.144     2686.144                    0                      0
# 4    4   2686.144     2686.144                    0                      0
#
#    RemainingDebt_enero  RemainingDebt_febrero   estado
# 0               203.19                 204.43  Jalisco
# 1                42.78                  42.63  Jalisco
# 2               190.63                 189.87  Jalisco
# 3                52.00                  51.81  Jalisco
# 4               194.85                 197.55  Jalisco

# %%
Table["saldo_pesosE"] = Table["vsm_enero"]*Table["RemainingDebt_enero"]
Table["saldo_pesosF"] = Table["vsm_febrero"]*Table["RemainingDebt_febrero"]
Table["DueDaysE"] = Table["PagosVencidos_enero"]*30
Table["DueDaysF"] = Table["PagosVencidos_febrero"]*30
Table.head()
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#    key  vsm_enero  vsm_febrero  PagosVencidos_enero  PagosVencidos_febrero  \
# 0    0   2686.144     2686.144                    0                      0
# 1    1   2686.144     2686.144                    0                      0
# 2    2   2686.144     2686.144                    0                      0
# 3    3   2686.144     2686.144                    0                      0
# 4    4   2686.144     2686.144                    0                      0
#
#    RemainingDebt_enero  RemainingDebt_febrero   estado  saldo_pesosE  \
# 0               203.19                 204.43  Jalisco  545797.59936
# 1                42.78                  42.63  Jalisco  114913.24032
# 2               190.63                 189.87  Jalisco  512059.63072
# 3                52.00                  51.81  Jalisco  139679.48800
# 4               194.85                 197.55  Jalisco  523395.15840
#
#    saldo_pesosF  DueDaysE  DueDaysF
# 0  549128.41792         0         0
# 1  114510.31872         0         0
# 2  510018.16128         0         0
# 3  139169.12064         0         0
# 4  530647.74720         0         0

# %%
Table["DueDaysE"].value_counts()
# Out:
# 0     16856
# 30     1289
# 60      248
# 90       53
# Name: DueDaysE, dtype: int64

# %%
Table["DueDaysF"].value_counts()
# Out:
# 0      16509
# 30      1490
# 60       344
# 90        72
# 120       31
# Name: DueDaysF, dtype: int64

# %%
len(Table)
# Out:
# 18446

# %%
Performance_Stay = Table.loc[Table["DueDaysE"] == Table["DueDaysF"] , :]
Performance_Stay["Performance"] = "stay"
Performance_Stay.head()
#Performance_Stay.count()
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    key  vsm_enero  vsm_febrero  PagosVencidos_enero  PagosVencidos_febrero  \
# 0    0   2686.144     2686.144                    0                      0
# 1    1   2686.144     2686.144                    0                      0
# 2    2   2686.144     2686.144                    0                      0
# 3    3   2686.144     2686.144                    0                      0
# 4    4   2686.144     2686.144                    0                      0
#
#    RemainingDebt_enero  RemainingDebt_febrero   estado  saldo_pesosE  \
# 0               203.19                 204.43  Jalisco  545797.59936
# 1                42.78                  42.63  Jalisco  114913.24032
# 2               190.63                 189.87  Jalisco  512059.63072
# 3                52.00                  51.81  Jalisco  139679.48800
# 4               194.85                 197.55  Jalisco  523395.15840
#
#    saldo_pesosF  DueDaysE  DueDaysF Performance
# 0  549128.41792         0         0        stay
# 1  114510.31872         0         0        stay
# 2  510018.16128         0         0        stay
# 3  139169.12064         0         0        stay
# 4  530647.74720         0         0        stay

# %%
Performance_Rol = Table.loc[Table["DueDaysE"] < Table["DueDaysF"] , :]
Performance_Rol["Performance"] = "Rol"
Performance_Rol.head()
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     key  vsm_enero  vsm_febrero  PagosVencidos_enero  PagosVencidos_febrero  \
# 9     9   2686.144     2686.144                    0                      1
# 13   13   2686.144     2686.144                    1                      2
# 17   17   2686.144     2686.144                    0                      1
# 24   24   2686.144     2686.144                    0                      1
# 30   30   2686.144     2686.144                    0                      1
#
#     RemainingDebt_enero  RemainingDebt_febrero   estado  saldo_pesosE  \
# 9                114.24                 115.02  Jalisco  306865.09056
# 13               166.01                 166.58  Jalisco  445926.76544
# 17               102.93                 102.08  Jalisco  276484.80192
# 24                77.36                  77.09  Jalisco  207800.09984
# 30               128.72                 129.51  Jalisco  345760.45568
#
#     saldo_pesosF  DueDaysE  DueDaysF Performance
# 9   308960.28288         0        30         Rol
# 13  447457.86752        30        60         Rol
# 17  274201.57952         0        30         Rol
# 24  207074.84096         0        30         Rol
# 30  347882.50944         0        30         Rol

# %%
Performance_Cure = Table.loc[Table["DueDaysE"] > Table["DueDaysF"] , :]
Performance_Cure["Performance"] = "Cure"
Performance_Cure.head()
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      key  vsm_enero  vsm_febrero  PagosVencidos_enero  PagosVencidos_febrero  \
# 45    45   2686.144     2686.144                    1                      0
# 77    77   2686.144     2686.144                    1                      0
# 85    85   2686.144     2686.144                    1                      0
# 211  211   2686.144     2686.144                    1                      0
# 277  277   2686.144     2686.144                    1                      0
#
#      RemainingDebt_enero  RemainingDebt_febrero           estado  \
# 45                 94.21                  93.01          Jalisco
# 77                 92.44                  91.08          Jalisco
# 85                189.04                 181.20  San Luis Potosi
# 211               127.18                 123.16  San Luis Potosi
# 277               139.98                 139.32  San Luis Potosi
#
#      saldo_pesosE  saldo_pesosF  DueDaysE  DueDaysF Performance
# 45   253061.62624  249838.25344        30         0        Cure
# 77   248307.15136  244653.99552        30         0        Cure
# 85   507788.66176  486729.29280        30         0        Cure
# 211  341623.79392  330825.49504        30         0        Cure
# 277  376006.43712  374233.58208        30         0        Cure

# %%
PerformanceT = [Performance_Stay, Performance_Rol, Performance_Cure]
result = pd.concat(PerformanceT).reset_index()
result.head()
#len(result)
# Out:
#    index  key  vsm_enero  vsm_febrero  PagosVencidos_enero  \
# 0      0    0   2686.144     2686.144                    0
# 1      1    1   2686.144     2686.144                    0
# 2      2    2   2686.144     2686.144                    0
# 3      3    3   2686.144     2686.144                    0
# 4      4    4   2686.144     2686.144                    0
#
#    PagosVencidos_febrero  RemainingDebt_enero  RemainingDebt_febrero   estado  \
# 0                      0               203.19                 204.43  Jalisco
# 1                      0                42.78                  42.63  Jalisco
# 2                      0               190.63                 189.87  Jalisco
# 3                      0                52.00                  51.81  Jalisco
# 4                      0               194.85                 197.55  Jalisco
#
#    saldo_pesosE  saldo_pesosF  DueDaysE  DueDaysF Performance
# 0  545797.59936  549128.41792         0         0        stay
# 1  114913.24032  114510.31872         0         0        stay
# 2  512059.63072  510018.16128         0         0        stay
# 3  139679.48800  139169.12064         0         0        stay
# 4  523395.15840  530647.74720         0         0        stay

# %%
result["Performance"].value_counts()
# Out:
# stay    16636
# Rol      1223
# Cure      587
# Name: Performance, dtype: int64

# %%
result.dtypes
# Out:
# index                      int64
# key                        int64
# vsm_enero                float64
# 18441   Baja California  1.037765e+06  1.036905e+06        30         0
# 18442  Estado de Mexico  3.614744e+05  3.574989e+05        30         0
# 18443   San Luis Potosi  7.724007e+05  7.691773e+05        30         0
# 18444         Chihuahua  2.307666e+05  2.254212e+05        30         0
# 18445        Nuevo Leon  5.395657e+05  5.261619e+05        30         0
#
#       Performance  jump
# 0            stay     0
# 1            stay     0
# 2            stay     0
# 3            stay     0
# 4            stay     0
# 5            stay     0
# 6            stay     0
# 7            stay     0
# 8            stay     0
# 9            stay     0
# 10           stay     0
# 11           stay     0
# 12           stay     0
# 13           stay     0
# 14           stay     0
# 15           stay     0
# 16           stay     0
# 17           stay     0
# 18           stay     0
# 19           stay     0
# 20           stay     0
# 21           stay     0
# 22           stay     0
# 23           stay     0
# 24           stay     0
# 25           stay     0
# 26           stay     0
# 27           stay     0
# 28           stay     0
# 29           stay     0
# ...           ...   ...
# 18416        Cure   -30
# 18417        Cure   -30
# 18418        Cure   -30
# 18419        Cure   -30
# 18420        Cure   -30
# 18421        Cure   -60
# 18422        Cure   -30
# 18423        Cure   -30
# 18424        Cure   -30
# 18425        Cure   -30
# 18426        Cure   -30
# 18427        Cure   -30
# 18428        Cure   -30
# 18429        Cure   -30
# 18430        Cure   -30
# 18431        Cure   -60
# 18432        Cure   -30
# 18433        Cure   -30
# 18434        Cure   -30
# 18435        Cure   -30
# 18436        Cure   -30
# 18437        Cure   -30
# 18438        Cure   -60
# 18439        Cure   -30
# 18440        Cure   -30
# 18441        Cure   -30
# 18442        Cure   -30
# 18443        Cure   -30
# 18444        Cure   -30
# 18445        Cure   -30
#
# [18446 rows x 15 columns]

# %%
result["jump"].value_counts()
# Out:
#  0     16636
#  30     1223
# -30      535
# -60       42
# -90       10
# Name: jump, dtype: int64

# %%
# analyze past due days, ok use duedays.
result['PagosVencidos_enero'].value_counts()
result['PagosVencidos_febrero'].value_counts()
# Out:
# 0    16509
# 1     1490
# 2      344
# 3       72
# 4       31
# Name: PagosVencidos_febrero, dtype: int64

# %%
# indentify 90+ to determine bad rate
result['pay_nopay'] = np.where(result['DueDaysF']>=90, 1, 0)
result['pay_nopay'].value_counts()
# Out:
# 0    18343
# 1      103
# Name: pay_nopay, dtype: int64

# %%
# group by economical zones = 8 since there are different sizes better group this way
#source https://es.wikipedia.org/wiki/Anexo:Zonas_econ%C3%B3micas_de_M%C3%A9xico

zn = {'Baja California': 'NOR', 'Baja California Sur': 'NOR', 'Chihuahua': 'NOR', 'Durango': 'NOR','Sinaloa':'NOR','Sonora':'NOR',
       'Coahuila': 'NES', 'Nuevo Leon': 'NES', 'Tamaulipas': 'NES',
      'Colima': 'OCC', 'Jalisco': 'OCC', 'Michoacan': 'OCC', 'Nayarit': 'OCC',
       'Hidalgo': 'ORI', 'Puebla': 'ORI', 'Tlaxcala': 'ORI', 'Veracruz': 'ORI',
      'Aguascalientes': 'CNO', 'Guanajuato': 'CNO', 'Queretaro': 'CNO', 'San Luis Potosi': 'CNO','Zacatecas': 'CNO',
      'Ciudad de Mexico': 'CSU', 'Estado de Mexico': 'CSU', 'Morelos': 'CSU',
      'Chiapas': 'SUO', 'Guerrero': 'SUO', 'Oaxaca': 'SUO',
      'Campeche': 'SUE','Quintana Roo': 'SUE', 'Tabasco': 'SUE', 'Yucatan': 'SUE'
     }

result['zone'] = result['estado'].map(zn)
result['zone'].value_counts()
# Out:
# NOR    4870
# NES    2921
# OCC    2822
# CSU    2448
# CNO    2011
# ORI    1164
# SUE    1115
# SUO     687
# Name: zone, dtype: int64

# %%
#plot distribution by economical zone
#pending how to get with value_counts

import matplotlib.pyplot as plt
# %matplotlib inline
#NOR    4870
#NES    2921
#OCC    2822
#CSU    2448
#CNO    2011
#ORI    1164
#SUE    1115
#SUO     687
labels = 'NOR', 'NES', 'OCC', 'CSU','CNO','ORI','SUE','SUO'
sizes = [4870, 2921, 2822, 2448, 2011, 1164,1115,687]
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0.1, 0, 0, 0,0,0,0,0)
#plt.pie(sizes, explode=explode, labels=labels, colors=colors,
#autopct='%1.1f%%', shadow=True, startangle=90)
plt.pie(sizes, explode=explode, labels=labels,autopct='%1.1f%%')
plt.axis('equal')
plt.title('Distribution of credits per Economical Zone')
plt.show()

# %%
#analyze bad rate per entity
#make groups by entity

res_stat=result.groupby('estado')['pay_nopay'].agg(['sum', 'count'])
res_stat_DF=pd.DataFrame(res_stat).reindex()
#res_stat_DF.rename(columns={'sum':'bad','count':'total'}) #ver porque no sirve
res_stat_DF.rename(columns={'sum':'pay_nopay','count':'total'}) #ver porque no sirve
res_stat_DF['nopay_rate']=round((res_stat_DF['sum']/res_stat_DF['count'])*100,2)
res_stat_DF.reset_index()
# Out:
#                  estado  sum  count  nopay_rate
# 0        Aguascalientes    0    161        0.00
# 1       Baja California   11   1985        0.55
# 2   Baja California Sur    3    579        0.52
# 3              Campeche    1     24        4.17
# 4               Chiapas    1    197        0.51
# 5             Chihuahua    2    979        0.20
# 6              Coahuila    1    409        0.24
# 7                Colima    0     60        0.00
# 8      Distrito Federal    4    408        0.98
# 9               Durango    1     52        1.92
# 10     Estado de Mexico   18   2339        0.77
# 11           Guanajuato    1    517        0.19
# 12             Guerrero    3    162        1.85
# 13              Hidalgo    0     88        0.00
# 14              Jalisco   14   2354        0.59
# 15            Michoacan    0    206        0.00
# 16              Morelos    1    109        0.92
# 17              Nayarit    1    202        0.50
# 18           Nuevo Leon   11   1532        0.72
# 19               Oaxaca    0    328        0.00
# 20               Puebla    1    539        0.19
# 21            Queretaro    2    379        0.53
# 22         Quintana Roo   10    987        1.01
# 23      San Luis Potosi    1    894        0.11
# 24              Sinaloa    2    578        0.35
# 25               Sonora    3    697        0.43
# 26              Tabasco    0     60        0.00
# 27           Tamaulipas    9    980        0.92
# 28             Tlaxcala    0     14        0.00
# 29             Veracruz    2    523        0.38
# 30              Yucatan    0     44        0.00
# 31            Zacatecas    0     60        0.00

# %%
#plot bad rate per state
res_stat_DF.head()
res_stat_DF.reset_index()
#res_stat_DF.set_index('estado')
res_stat_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Aguascalientes to Zacatecas
# Data columns (total 3 columns):
# sum           32 non-null int32
# count         32 non-null int64
# nopay_rate    32 non-null float64
# dtypes: float64(1), int32(1), int64(1)
# memory usage: 896.0+ bytes

# %%
#transition matriz payments
#group by payment january &February then cross table

#Transition Matriz for payment jan vs. Feb to see migration#"result.pivot_table(index=['PagosVencidos_enero'],columns=['PagosVencidos_febrero'],aggfunc='count')
mx = result[['PagosVencidos_enero','PagosVencidos_febrero']]
mx.groupby['PagosVencidos_enero','PagosVencidos_febrero']
#pd.pivot_table(mx,index='PagosVencidos_enero', values='PagosVencidos_enero',columns='PagosVencidos_febrero',aggfunc='count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-7f16b292a0ac> in <module>
#       4 #Transition Matriz for payment jan vs. Feb to see migration#"result.pivot_table(index=['PagosVencidos_enero'],columns=['PagosVencidos_febrero'],aggfunc='count')
#       5 mx = result[['PagosVencidos_enero','PagosVencidos_febrero']]
# ----> 6 mx.groupby['PagosVencidos_enero','PagosVencidos_febrero']
#       7 #pd.pivot_table(mx,index='PagosVencidos_enero', values='PagosVencidos_enero',columns='PagosVencidos_febrero',aggfunc='count')
#
# TypeError: 'method' object is not subscriptable

# %%
#CNBV Banking portfolio composition vs BBVA - Mortgage credits
#add source
cnbv=pd.read_csv('cartera_comparaCNBV.csv')
#cnbv_DF=pd.DataFrame(cnbv_balance)
cnbv['STot']=cnbv['sdo_total'].astype(int)
cnbv['SVig']=cnbv['sdo_vigente'].astype(int)
cnbv['SVen']=cnbv['sdo_vencido'].astype(int)
cnbv['NTot']=cnbv['num_total'].astype(int)
cnbv['NVig']=cnbv['num_vigente'].astype(int)
cnbv['NVen']=cnbv['num_vencida'].astype(int)
del cnbv['sdo_total']
del cnbv['sdo_vigente']
del cnbv['sdo_vencido']
del cnbv['num_total']
del cnbv['num_vigente']
del cnbv['num_vencida']
cnbv_DF=pd.DataFrame(cnbv)
cnbv_DF

#calculate imor Banking (total) - mortgages
cnbv_DF['Per_IMOR']=round(((cnbv_DF.SVen)/(cnbv_DF.STot))*100,2)
cnbv_DF['Num_IMOR']=round(((cnbv_DF.NVen)/(cnbv_DF.NTot))*100,2)
cnbv_DF
# Out:
#     periodo institucion       STot       SVig      SVen    NTot    NVig  \
# 0    201905        BBVA  204014539  197789091   6225448  301448  291944
# 1    201904        BBVA  201796632  195593847   6202785  300504  290999
# 2    201903        BBVA  200486990  194968556   5518433  299980  291623
# 3    201902        BBVA  198194871  192212966   5981905  298869  289636
# 4    201901        BBVA  198194871  192212966   5981905  298869  289636
# 5    201812        BBVA  194593012  188874438   5718574  298135  288902
# 6    201811        BBVA  193111196  187327592   5783605  297885  288521
# 7    201810        BBVA  191460075  185847137   5612938  297273  288174
# 8    201809        BBVA  190336865  184952667   5384198  297606  288887
# 9    201808        BBVA  188540135  182631116   5909019  296878  287112
# 10   201807        BBVA  187441546  181500822   5940724  296622  286739
# 11   201806        BBVA  186721942  181402036   5319906  296800  288029
# 12   201905          BM  714237653  696229661  18007992  959135  933013
# 13   201904          BM  707489551  689945414  17544137  959026  933375
# 14   201903          BM  703712784  686798390  16914394  957125  932543
# 15   201902          BM  696215291  678919466  17295825  951060  925850
# 16   201901          BM  691848673  675124057  16724616  949904  924909
# 17   201812          BM  687653559  671055553  16598006  950617  925687
# 18   201811          BM  680248220  663947436  16300785  946441  921809
# 19   201810          BM  674830374  659021692  15808682  944907  921214
# 20   201809          BM  670732825  654994848  15737977  943252  919643
# 21   201808          BM  663616356  647575620  16040735  940257  915928
# 22   201807          BM  659786785  643580045  16206740  938875  914241
# 23   201806          BM  654570915  639165974  15404941  936861  913708
#
#      NVen  Per_IMOR  Num_IMOR
# 0    9504      3.05      3.15
# 1    9505      3.07      3.16
# 2    8357      2.75      2.79
# 3    9233      3.02      3.09
# 4    9233      3.02      3.09
# 5    9233      2.94      3.10
# 6    9364      2.99      3.14
# 7    9099      2.93      3.06
# 8    8719      2.83      2.93
# 9    9766      3.13      3.29
# 10   9883      3.17      3.33
# 11   8771      2.85      2.96
# 12  26122      2.52      2.72
# 13  25651      2.48      2.67
# 14  24582      2.40      2.57
# 15  25210      2.48      2.65
# 16  24995      2.42      2.63
# 17  24930      2.41      2.62
# 18  24632      2.40      2.60
# 19  23693      2.34      2.51
# 20  23609      2.35      2.50
# 21  24329      2.42      2.59
# 22  24634      2.46      2.62
# 23  23153      2.35      2.47

# %%
imor_bbva=cnbv_DF.loc[cnbv_DF['institucion']=='BBVA', ['periodo','Per_IMOR']].reindex()
imor_bbva
imor_banking=cnbv_DF.loc[cnbv_DF['institucion']=='BM', ['periodo','Per_IMOR']].reset_index()
imor_banking
une_imor=pd.merge(imor_bbva, imor_banking, on='periodo', how='inner')
del une_imor['index']
une_imor
# Out:
#     periodo  Per_IMOR_x  Per_IMOR_y
# 0    201905        3.05        2.52
# 1    201904        3.07        2.48
# 2    201903        2.75        2.40
# 3    201902        3.02        2.48
# 4    201901        3.02        2.42
# 5    201812        2.94        2.41
# 6    201811        2.99        2.40
# 7    201810        2.93        2.34
# 8    201809        2.83        2.35
# 9    201808        3.13        2.42
# 10   201807        3.17        2.46
# 11   201806        2.85        2.35

# %%
#plot tendencies Banking vs BBVA
x_axis=une_imor.Per_IMOR_x
#y_axis=une_imor.periodo
plt.plot(x_axis)

# %%
#anova: Bad rate depends on state
#    Ho. Bad Rate is equal in every state
#    H1 Bad rate behaves equal.. doesnt depends on states
# Etract individual groups per state


# Perform the ANOVA
#stats.f_oneway(asian, black, hispanic, other, white)

# %%
#plot balances, number of credits.. descriptive..
#stats median max mode.. etc archi richie
